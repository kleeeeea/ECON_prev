# %%
import cPickle
from gensim.models import word2vec
from gensim import corpora, models, similarities
import sys
import logging


INITIALIZE = True

logging.basicConfig(level=logging.DEBUG)

dataset = 'machine_learning'

queries = ['database_schema', '']
# if len(sys.argv) > 1:
#     dataset = sys.argv[1]

APPROACHES = ['rake']


def index(file_pureText):
    with open(file_pureText) as f:
        lines = f.readlines()

    logging.debug('processing %s' % file_pureText)
    try:
        if INITIALIZE:
            raise Exception
        corpus = corpora.MmCorpus(file_pureText + '.corpus')
        dictionary = corpora.Dictionary.load(file_pureText + '.dict')
        modelTfidf = models.TfidfModel.load(file_pureText + '.modelTfidf')
    except Exception, e:
        print 'using new model'
        wordsLists = [line.lower().split() for line in lines]
        dictionary = corpora.Dictionary(wordsLists)
        corpus = [dictionary.doc2bow(text) for text in wordsLists]
        modelTfidf = models.TfidfModel(corpus)

        dictionary.save(file_pureText + '.dict')  # store the dictionary, for future reference
        corpora.MmCorpus.serialize(file_pureText + '.corpus', corpus)  # store to disk, for later use
        corpus = corpora.MmCorpus(file_pureText+'.corpus')
        modelTfidf.save(file_pureText+'.modelTfidf')

    try:
        if INITIALIZE:
            raise Exception
        index = cPickle.load(open(file_pureText+'.index', 'rb'))
    except Exception, e:
        print 'using new index'
        modelTfidfCorpus = modelTfidf[corpus]
        index = similarities.Similarity(file_pureText+'.modelTfidfindex', modelTfidfCorpus, num_features=modelTfidfCorpus.corpus.num_terms)
        index.num_best = None
        cPickle.dump(index, open(file_pureText+'.index', 'wb'))

def process(dataset, approach):
    file_pureText = "/scratch/home/hwzha/workspace/%s/result/%s/merged.txt_without_sentence_id.evaluation.txt" % (approach, dataset)
    try:
        index(file_pureText)
    except Exception as e:
        print e
# Out:
# DEBUG:root:processing /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt
# using new model
# INFO:gensim.corpora.dictionary:adding document #0 to Dictionary(0 unique tokens: [])
# INFO:gensim.corpora.dictionary:adding document #10000 to Dictionary(26685 unique tokens: [u'<c>dilemmas_facing_medical_education</c>', u'telmisartan', u'<c>ursodeoxycholic_acid</c>', u'localized', u'<c>total_accumulated_dosage</c>']...)
# INFO:gensim.corpora.dictionary:adding document #20000 to Dictionary(46761 unique tokens: [u'<c>14_2</c>', u'<c>dilemmas_facing_medical_education</c>', u'telmisartan', u'normal-variant', u'<c>p_phenotypes</c>']...)
# INFO:gensim.corpora.dictionary:adding document #30000 to Dictionary(64238 unique tokens: [u'<c>14_2</c>', u'<c>dilemmas_facing_medical_education</c>', u'<c>toxoplasmosis_identifies_congenital_infections</c>', u'<c>first_pregnancy</c>', u'telmisartan']...)
# INFO:gensim.corpora.dictionary:adding document #40000 to Dictionary(80802 unique tokens: [u'<c>14_2</c>', u'<c>dilemmas_facing_medical_education</c>', u'<c>toxoplasmosis_identifies_congenital_infections</c>', u'<c>first_pregnancy</c>', u'telmisartan']...)
# INFO:gensim.corpora.dictionary:adding document #50000 to Dictionary(97641 unique tokens: [u'<c>dilemmas_facing_medical_education</c>', u'<c>two_unrelated_infants</c>', u'<c>sequential_drug_combinations</c>', u'<c>p_phenotypes</c>', u'<c>initial_24_hours</c>']...)
# INFO:gensim.corpora.dictionary:adding document #60000 to Dictionary(112488 unique tokens: [u'<c>dilemmas_facing_medical_education</c>', u'<c>two_unrelated_infants</c>', u'<c>sequential_drug_combinations</c>', u'<c>p_phenotypes</c>', u'<c>initial_24_hours</c>']...)
# INFO:gensim.corpora.dictionary:adding document #70000 to Dictionary(128487 unique tokens: [u'<c>designer_cigarettes</c>', u'<c>dilemmas_facing_medical_education</c>', u'<c>two_unrelated_infants</c>', u'<c>sequential_drug_combinations</c>', u'<c>p_phenotypes</c>']...)
# INFO:gensim.corpora.dictionary:adding document #80000 to Dictionary(149019 unique tokens: [u'<c>designer_cigarettes</c>', u'<c>dilemmas_facing_medical_education</c>', u'<c>heterogeneous_disease_phenotype</c>', u'<c>two_unrelated_infants</c>', u'<c>sequential_drug_combinations</c>']...)
# INFO:gensim.corpora.dictionary:adding document #90000 to Dictionary(174678 unique tokens: [u'<c>designer_cigarettes</c>', u'<c>major_subject</c>', u'<c>dilemmas_facing_medical_education</c>', u'<c>study_could_suggest</c>', u'<c>heterogeneous_disease_phenotype</c>']...)
# INFO:gensim.corpora.dictionary:adding document #100000 to Dictionary(198119 unique tokens: [u'<c>designer_cigarettes</c>', u'<c>major_subject</c>', u'<c>dilemmas_facing_medical_education</c>', u'<c>47_patients_13_percent_assigned</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #110000 to Dictionary(220195 unique tokens: [u'<c>designer_cigarettes</c>', u'<c>major_subject</c>', u'<c>dilemmas_facing_medical_education</c>', u'<c>47_patients_13_percent_assigned</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #120000 to Dictionary(241100 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>major_subject</c>', u'<c>dilemmas_facing_medical_education</c>', u'<c>47_patients_13_percent_assigned</c>']...)
# INFO:gensim.corpora.dictionary:adding document #130000 to Dictionary(261075 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>major_subject</c>', u'<c>dilemmas_facing_medical_education</c>', u'<c>47_patients_13_percent_assigned</c>']...)
# INFO:gensim.corpora.dictionary:adding document #140000 to Dictionary(281132 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>major_subject</c>', u'<c>dilemmas_facing_medical_education</c>', u'<c>47_patients_13_percent_assigned</c>']...)
# INFO:gensim.corpora.dictionary:adding document #150000 to Dictionary(300335 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>major_subject</c>', u'-methylene', u'<c>dilemmas_facing_medical_education</c>']...)
# INFO:gensim.corpora.dictionary:adding document #160000 to Dictionary(319661 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>major_subject</c>', u'-methylene', u'<c>dilemmas_facing_medical_education</c>']...)
# INFO:gensim.corpora.dictionary:adding document #170000 to Dictionary(338420 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>major_subject</c>', u'-methylene', u'<c>dilemmas_facing_medical_education</c>']...)
# INFO:gensim.corpora.dictionary:adding document #180000 to Dictionary(356264 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>foreign_bodies_10_vs_67_mortality</c>']...)
# INFO:gensim.corpora.dictionary:adding document #190000 to Dictionary(371868 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>foreign_bodies_10_vs_67_mortality</c>']...)
# INFO:gensim.corpora.dictionary:adding document #200000 to Dictionary(387164 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>foreign_bodies_10_vs_67_mortality</c>']...)
# INFO:gensim.corpora.dictionary:adding document #210000 to Dictionary(401282 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>foreign_bodies_10_vs_67_mortality</c>']...)
# INFO:gensim.corpora.dictionary:adding document #220000 to Dictionary(415407 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>foreign_bodies_10_vs_67_mortality</c>']...)
# INFO:gensim.corpora.dictionary:adding document #230000 to Dictionary(428474 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>foreign_bodies_10_vs_67_mortality</c>']...)
# INFO:gensim.corpora.dictionary:adding document #240000 to Dictionary(442445 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>foreign_bodies_10_vs_67_mortality</c>']...)
# INFO:gensim.corpora.dictionary:adding document #250000 to Dictionary(456110 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>foreign_bodies_10_vs_67_mortality</c>']...)
# INFO:gensim.corpora.dictionary:adding document #260000 to Dictionary(469273 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>foreign_bodies_10_vs_67_mortality</c>']...)
# INFO:gensim.corpora.dictionary:adding document #270000 to Dictionary(482731 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>foreign_bodies_10_vs_67_mortality</c>']...)
# INFO:gensim.corpora.dictionary:adding document #280000 to Dictionary(496334 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>foreign_bodies_10_vs_67_mortality</c>']...)
# INFO:gensim.corpora.dictionary:adding document #290000 to Dictionary(510413 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>foreign_bodies_10_vs_67_mortality</c>']...)
# INFO:gensim.corpora.dictionary:adding document #300000 to Dictionary(523529 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>foreign_bodies_10_vs_67_mortality</c>']...)
# INFO:gensim.corpora.dictionary:adding document #310000 to Dictionary(536489 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>two_unrelated_infants</c>', u'<c>stress_appear</c>']...)
# INFO:gensim.corpora.dictionary:adding document #320000 to Dictionary(549518 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>public_hospital_emergency_departments</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #330000 to Dictionary(561715 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>public_hospital_emergency_departments</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #340000 to Dictionary(573846 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>public_hospital_emergency_departments</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #350000 to Dictionary(587571 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>public_hospital_emergency_departments</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #360000 to Dictionary(601165 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>collagen_result</c>', u'<c>public_hospital_emergency_departments</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #370000 to Dictionary(614721 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>vertical_transmission_implies_transmission</c>', u'<c>collagen_result</c>', u'<c>public_hospital_emergency_departments</c>']...)
# INFO:gensim.corpora.dictionary:adding document #380000 to Dictionary(628771 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>vertical_transmission_implies_transmission</c>', u'<c>collagen_result</c>', u'<c>public_hospital_emergency_departments</c>']...)
# INFO:gensim.corpora.dictionary:adding document #390000 to Dictionary(641978 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>vertical_transmission_implies_transmission</c>', u'<c>collagen_result</c>', u'<c>public_hospital_emergency_departments</c>']...)
# INFO:gensim.corpora.dictionary:adding document #400000 to Dictionary(655501 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>vertical_transmission_implies_transmission</c>', u'<c>collagen_result</c>', u'<c>public_hospital_emergency_departments</c>']...)
# INFO:gensim.corpora.dictionary:adding document #410000 to Dictionary(667930 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>vertical_transmission_implies_transmission</c>', u'<c>collagen_result</c>', u'<c>public_hospital_emergency_departments</c>']...)
# INFO:gensim.corpora.dictionary:adding document #420000 to Dictionary(680559 unique tokens: [u'<c>although_correctional_facilities_also_represent</c>', u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>vertical_transmission_implies_transmission</c>', u'<c>collagen_result</c>']...)
# INFO:gensim.corpora.dictionary:adding document #430000 to Dictionary(693199 unique tokens: [u'<c>although_correctional_facilities_also_represent</c>', u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>vertical_transmission_implies_transmission</c>', u'<c>collagen_result</c>']...)
# INFO:gensim.corpora.dictionary:adding document #440000 to Dictionary(705673 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #450000 to Dictionary(718491 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #460000 to Dictionary(730665 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #470000 to Dictionary(742990 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #480000 to Dictionary(755185 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #490000 to Dictionary(768489 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #500000 to Dictionary(782668 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #510000 to Dictionary(796451 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #520000 to Dictionary(810051 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #530000 to Dictionary(822825 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #540000 to Dictionary(834123 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #550000 to Dictionary(847114 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #560000 to Dictionary(860612 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #570000 to Dictionary(873582 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #580000 to Dictionary(886752 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #590000 to Dictionary(899648 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>', u'<c>two_unrelated_infants</c>']...)
# INFO:gensim.corpora.dictionary:adding document #600000 to Dictionary(911729 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #610000 to Dictionary(922406 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #620000 to Dictionary(934789 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #630000 to Dictionary(947088 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #640000 to Dictionary(960145 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #650000 to Dictionary(972630 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #660000 to Dictionary(984015 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #670000 to Dictionary(996764 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #680000 to Dictionary(1010187 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #690000 to Dictionary(1022833 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #700000 to Dictionary(1034939 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #710000 to Dictionary(1047591 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #720000 to Dictionary(1059977 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #730000 to Dictionary(1071790 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #740000 to Dictionary(1083351 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #750000 to Dictionary(1095232 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #760000 to Dictionary(1110674 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #770000 to Dictionary(1128287 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #780000 to Dictionary(1145276 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #790000 to Dictionary(1162166 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #800000 to Dictionary(1176522 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #810000 to Dictionary(1187403 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #820000 to Dictionary(1199547 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #830000 to Dictionary(1211264 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #840000 to Dictionary(1223277 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #850000 to Dictionary(1234746 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #860000 to Dictionary(1246023 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>', u'<c>carbon_14</c>']...)
# INFO:gensim.corpora.dictionary:adding document #870000 to Dictionary(1257584 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'unsupportable', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>']...)
# INFO:gensim.corpora.dictionary:adding document #880000 to Dictionary(1268682 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'unsupportable', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>']...)
# INFO:gensim.corpora.dictionary:adding document #890000 to Dictionary(1279727 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'unsupportable', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>']...)
# INFO:gensim.corpora.dictionary:built Dictionary(1286331 unique tokens: [u'<c>least_4_weeks</c>', u'<c>designer_cigarettes</c>', u'unsupportable', u'<c>acquired_hiv</c>', u'<c>www_elsevier_com_locate_ajmselect</c>']...) from 895833 documents (total 11664068 corpus positions)
# INFO:gensim.models.tfidfmodel:collecting document frequencies
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #0
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #10000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #20000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #30000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #40000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #50000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #60000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #70000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #80000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #90000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #100000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #110000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #120000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #130000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #140000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #150000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #160000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #170000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #180000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #190000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #200000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #210000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #220000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #230000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #240000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #250000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #260000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #270000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #280000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #290000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #300000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #310000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #320000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #330000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #340000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #350000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #360000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #370000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #380000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #390000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #400000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #410000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #420000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #430000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #440000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #450000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #460000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #470000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #480000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #490000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #500000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #510000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #520000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #530000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #540000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #550000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #560000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #570000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #580000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #590000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #600000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #610000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #620000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #630000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #640000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #650000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #660000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #670000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #680000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #690000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #700000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #710000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #720000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #730000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #740000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #750000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #760000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #770000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #780000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #790000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #800000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #810000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #820000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #830000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #840000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #850000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #860000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #870000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #880000
# INFO:gensim.models.tfidfmodel:PROGRESS: processing document #890000
# INFO:gensim.models.tfidfmodel:calculating IDF weights for 895833 documents and 1286330 features (10196763 matrix non-zeros)
# INFO:gensim.utils:saving Dictionary object under /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.dict, separately None
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'wb', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.dict'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.dict', mode 'wb' at 0x7f056a55c780>, 'encoding': None}
# INFO:gensim.utils:saved /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.dict
# INFO:gensim.corpora.mmcorpus:storing corpus in Matrix Market format to /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.corpus
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'wb+', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.corpus'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb+', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.corpus', mode 'wb+' at 0x7f056a55c5d0>, 'encoding': None}
# INFO:gensim.matutils:saving sparse matrix to /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.corpus
# INFO:gensim.matutils:PROGRESS: saving document #0
# INFO:gensim.matutils:PROGRESS: saving document #1000
# INFO:gensim.matutils:PROGRESS: saving document #2000
# INFO:gensim.matutils:PROGRESS: saving document #3000
# INFO:gensim.matutils:PROGRESS: saving document #4000
# INFO:gensim.matutils:PROGRESS: saving document #5000
# INFO:gensim.matutils:PROGRESS: saving document #6000
# INFO:gensim.matutils:PROGRESS: saving document #7000
# INFO:gensim.matutils:PROGRESS: saving document #8000
# INFO:gensim.matutils:PROGRESS: saving document #9000
# INFO:gensim.matutils:PROGRESS: saving document #10000
# INFO:gensim.matutils:PROGRESS: saving document #11000
# INFO:gensim.matutils:PROGRESS: saving document #12000
# INFO:gensim.matutils:PROGRESS: saving document #13000
# INFO:gensim.matutils:PROGRESS: saving document #14000
# INFO:gensim.matutils:PROGRESS: saving document #15000
# INFO:gensim.matutils:PROGRESS: saving document #16000
# INFO:gensim.matutils:PROGRESS: saving document #17000
# INFO:gensim.matutils:PROGRESS: saving document #18000
# INFO:gensim.matutils:PROGRESS: saving document #19000
# INFO:gensim.matutils:PROGRESS: saving document #20000
# INFO:gensim.matutils:PROGRESS: saving document #21000
# INFO:gensim.matutils:PROGRESS: saving document #22000
# INFO:gensim.matutils:PROGRESS: saving document #23000
# INFO:gensim.matutils:PROGRESS: saving document #24000
# INFO:gensim.matutils:PROGRESS: saving document #25000
# INFO:gensim.matutils:PROGRESS: saving document #26000
# INFO:gensim.matutils:PROGRESS: saving document #27000
# INFO:gensim.matutils:PROGRESS: saving document #28000
# INFO:gensim.matutils:PROGRESS: saving document #29000
# INFO:gensim.matutils:PROGRESS: saving document #30000
# INFO:gensim.matutils:PROGRESS: saving document #31000
# INFO:gensim.matutils:PROGRESS: saving document #32000
# INFO:gensim.matutils:PROGRESS: saving document #33000
# INFO:gensim.matutils:PROGRESS: saving document #34000
# INFO:gensim.matutils:PROGRESS: saving document #35000
# INFO:gensim.matutils:PROGRESS: saving document #36000
# INFO:gensim.matutils:PROGRESS: saving document #37000
# INFO:gensim.matutils:PROGRESS: saving document #38000
# INFO:gensim.matutils:PROGRESS: saving document #39000
# INFO:gensim.matutils:PROGRESS: saving document #40000
# INFO:gensim.matutils:PROGRESS: saving document #41000
# INFO:gensim.matutils:PROGRESS: saving document #42000
# INFO:gensim.matutils:PROGRESS: saving document #43000
# INFO:gensim.matutils:PROGRESS: saving document #44000
# INFO:gensim.matutils:PROGRESS: saving document #45000
# INFO:gensim.matutils:PROGRESS: saving document #46000
# INFO:gensim.matutils:PROGRESS: saving document #47000
# INFO:gensim.matutils:PROGRESS: saving document #48000
# INFO:gensim.matutils:PROGRESS: saving document #49000
# INFO:gensim.matutils:PROGRESS: saving document #50000
# INFO:gensim.matutils:PROGRESS: saving document #51000
# INFO:gensim.matutils:PROGRESS: saving document #52000
# INFO:gensim.matutils:PROGRESS: saving document #53000
# INFO:gensim.matutils:PROGRESS: saving document #54000
# INFO:gensim.matutils:PROGRESS: saving document #55000
# INFO:gensim.matutils:PROGRESS: saving document #56000
# INFO:gensim.matutils:PROGRESS: saving document #57000
# INFO:gensim.matutils:PROGRESS: saving document #58000
# INFO:gensim.matutils:PROGRESS: saving document #59000
# INFO:gensim.matutils:PROGRESS: saving document #60000
# INFO:gensim.matutils:PROGRESS: saving document #61000
# INFO:gensim.matutils:PROGRESS: saving document #62000
# INFO:gensim.matutils:PROGRESS: saving document #63000
# INFO:gensim.matutils:PROGRESS: saving document #64000
# INFO:gensim.matutils:PROGRESS: saving document #65000
# INFO:gensim.matutils:PROGRESS: saving document #66000
# INFO:gensim.matutils:PROGRESS: saving document #67000
# INFO:gensim.matutils:PROGRESS: saving document #68000
# INFO:gensim.matutils:PROGRESS: saving document #69000
# INFO:gensim.matutils:PROGRESS: saving document #70000
# INFO:gensim.matutils:PROGRESS: saving document #71000
# INFO:gensim.matutils:PROGRESS: saving document #72000
# INFO:gensim.matutils:PROGRESS: saving document #73000
# INFO:gensim.matutils:PROGRESS: saving document #74000
# INFO:gensim.matutils:PROGRESS: saving document #75000
# INFO:gensim.matutils:PROGRESS: saving document #76000
# INFO:gensim.matutils:PROGRESS: saving document #77000
# INFO:gensim.matutils:PROGRESS: saving document #78000
# INFO:gensim.matutils:PROGRESS: saving document #79000
# INFO:gensim.matutils:PROGRESS: saving document #80000
# INFO:gensim.matutils:PROGRESS: saving document #81000
# INFO:gensim.matutils:PROGRESS: saving document #82000
# INFO:gensim.matutils:PROGRESS: saving document #83000
# INFO:gensim.matutils:PROGRESS: saving document #84000
# INFO:gensim.matutils:PROGRESS: saving document #85000
# INFO:gensim.matutils:PROGRESS: saving document #86000
# INFO:gensim.matutils:PROGRESS: saving document #87000
# INFO:gensim.matutils:PROGRESS: saving document #88000
# INFO:gensim.matutils:PROGRESS: saving document #89000
# INFO:gensim.matutils:PROGRESS: saving document #90000
# INFO:gensim.matutils:PROGRESS: saving document #91000
# INFO:gensim.matutils:PROGRESS: saving document #92000
# INFO:gensim.matutils:PROGRESS: saving document #93000
# INFO:gensim.matutils:PROGRESS: saving document #94000
# INFO:gensim.matutils:PROGRESS: saving document #95000
# INFO:gensim.matutils:PROGRESS: saving document #96000
# INFO:gensim.matutils:PROGRESS: saving document #97000
# INFO:gensim.matutils:PROGRESS: saving document #98000
# INFO:gensim.matutils:PROGRESS: saving document #99000
# INFO:gensim.matutils:PROGRESS: saving document #100000
# INFO:gensim.matutils:PROGRESS: saving document #101000
# INFO:gensim.matutils:PROGRESS: saving document #102000
# INFO:gensim.matutils:PROGRESS: saving document #103000
# INFO:gensim.matutils:PROGRESS: saving document #104000
# INFO:gensim.matutils:PROGRESS: saving document #105000
# INFO:gensim.matutils:PROGRESS: saving document #106000
# INFO:gensim.matutils:PROGRESS: saving document #107000
# INFO:gensim.matutils:PROGRESS: saving document #108000
# INFO:gensim.matutils:PROGRESS: saving document #109000
# INFO:gensim.matutils:PROGRESS: saving document #110000
# INFO:gensim.matutils:PROGRESS: saving document #111000
# INFO:gensim.matutils:PROGRESS: saving document #112000
# INFO:gensim.matutils:PROGRESS: saving document #113000
# INFO:gensim.matutils:PROGRESS: saving document #114000
# INFO:gensim.matutils:PROGRESS: saving document #115000
# INFO:gensim.matutils:PROGRESS: saving document #116000
# INFO:gensim.matutils:PROGRESS: saving document #117000
# INFO:gensim.matutils:PROGRESS: saving document #118000
# INFO:gensim.matutils:PROGRESS: saving document #119000
# INFO:gensim.matutils:PROGRESS: saving document #120000
# INFO:gensim.matutils:PROGRESS: saving document #121000
# INFO:gensim.matutils:PROGRESS: saving document #122000
# INFO:gensim.matutils:PROGRESS: saving document #123000
# INFO:gensim.matutils:PROGRESS: saving document #124000
# INFO:gensim.matutils:PROGRESS: saving document #125000
# INFO:gensim.matutils:PROGRESS: saving document #126000
# INFO:gensim.matutils:PROGRESS: saving document #127000
# INFO:gensim.matutils:PROGRESS: saving document #128000
# INFO:gensim.matutils:PROGRESS: saving document #129000
# INFO:gensim.matutils:PROGRESS: saving document #130000
# INFO:gensim.matutils:PROGRESS: saving document #131000
# INFO:gensim.matutils:PROGRESS: saving document #132000
# INFO:gensim.matutils:PROGRESS: saving document #133000
# INFO:gensim.matutils:PROGRESS: saving document #134000
# INFO:gensim.matutils:PROGRESS: saving document #135000
# INFO:gensim.matutils:PROGRESS: saving document #136000
# INFO:gensim.matutils:PROGRESS: saving document #137000
# INFO:gensim.matutils:PROGRESS: saving document #138000
# INFO:gensim.matutils:PROGRESS: saving document #139000
# INFO:gensim.matutils:PROGRESS: saving document #140000
# INFO:gensim.matutils:PROGRESS: saving document #141000
# INFO:gensim.matutils:PROGRESS: saving document #142000
# INFO:gensim.matutils:PROGRESS: saving document #143000
# INFO:gensim.matutils:PROGRESS: saving document #144000
# INFO:gensim.matutils:PROGRESS: saving document #145000
# INFO:gensim.matutils:PROGRESS: saving document #146000
# INFO:gensim.matutils:PROGRESS: saving document #147000
# INFO:gensim.matutils:PROGRESS: saving document #148000
# INFO:gensim.matutils:PROGRESS: saving document #149000
# INFO:gensim.matutils:PROGRESS: saving document #150000
# INFO:gensim.matutils:PROGRESS: saving document #151000
# INFO:gensim.matutils:PROGRESS: saving document #152000
# INFO:gensim.matutils:PROGRESS: saving document #153000
# INFO:gensim.matutils:PROGRESS: saving document #154000
# INFO:gensim.matutils:PROGRESS: saving document #155000
# INFO:gensim.matutils:PROGRESS: saving document #156000
# INFO:gensim.matutils:PROGRESS: saving document #157000
# INFO:gensim.matutils:PROGRESS: saving document #158000
# INFO:gensim.matutils:PROGRESS: saving document #159000
# INFO:gensim.matutils:PROGRESS: saving document #160000
# INFO:gensim.matutils:PROGRESS: saving document #161000
# INFO:gensim.matutils:PROGRESS: saving document #162000
# INFO:gensim.matutils:PROGRESS: saving document #163000
# INFO:gensim.matutils:PROGRESS: saving document #164000
# INFO:gensim.matutils:PROGRESS: saving document #165000
# INFO:gensim.matutils:PROGRESS: saving document #166000
# INFO:gensim.matutils:PROGRESS: saving document #167000
# INFO:gensim.matutils:PROGRESS: saving document #168000
# INFO:gensim.matutils:PROGRESS: saving document #169000
# INFO:gensim.matutils:PROGRESS: saving document #170000
# INFO:gensim.matutils:PROGRESS: saving document #171000
# INFO:gensim.matutils:PROGRESS: saving document #172000
# INFO:gensim.matutils:PROGRESS: saving document #173000
# INFO:gensim.matutils:PROGRESS: saving document #174000
# INFO:gensim.matutils:PROGRESS: saving document #175000
# INFO:gensim.matutils:PROGRESS: saving document #176000
# INFO:gensim.matutils:PROGRESS: saving document #177000
# INFO:gensim.matutils:PROGRESS: saving document #178000
# INFO:gensim.matutils:PROGRESS: saving document #179000
# INFO:gensim.matutils:PROGRESS: saving document #180000
# INFO:gensim.matutils:PROGRESS: saving document #181000
# INFO:gensim.matutils:PROGRESS: saving document #182000
# INFO:gensim.matutils:PROGRESS: saving document #183000
# INFO:gensim.matutils:PROGRESS: saving document #184000
# INFO:gensim.matutils:PROGRESS: saving document #185000
# INFO:gensim.matutils:PROGRESS: saving document #186000
# INFO:gensim.matutils:PROGRESS: saving document #187000
# INFO:gensim.matutils:PROGRESS: saving document #188000
# INFO:gensim.matutils:PROGRESS: saving document #189000
# INFO:gensim.matutils:PROGRESS: saving document #190000
# INFO:gensim.matutils:PROGRESS: saving document #191000
# INFO:gensim.matutils:PROGRESS: saving document #192000
# INFO:gensim.matutils:PROGRESS: saving document #193000
# INFO:gensim.matutils:PROGRESS: saving document #194000
# INFO:gensim.matutils:PROGRESS: saving document #195000
# INFO:gensim.matutils:PROGRESS: saving document #196000
# INFO:gensim.matutils:PROGRESS: saving document #197000
# INFO:gensim.matutils:PROGRESS: saving document #198000
# INFO:gensim.matutils:PROGRESS: saving document #199000
# INFO:gensim.matutils:PROGRESS: saving document #200000
# INFO:gensim.matutils:PROGRESS: saving document #201000
# INFO:gensim.matutils:PROGRESS: saving document #202000
# INFO:gensim.matutils:PROGRESS: saving document #203000
# INFO:gensim.matutils:PROGRESS: saving document #204000
# INFO:gensim.matutils:PROGRESS: saving document #205000
# INFO:gensim.matutils:PROGRESS: saving document #206000
# INFO:gensim.matutils:PROGRESS: saving document #207000
# INFO:gensim.matutils:PROGRESS: saving document #208000
# INFO:gensim.matutils:PROGRESS: saving document #209000
# INFO:gensim.matutils:PROGRESS: saving document #210000
# INFO:gensim.matutils:PROGRESS: saving document #211000
# INFO:gensim.matutils:PROGRESS: saving document #212000
# INFO:gensim.matutils:PROGRESS: saving document #213000
# INFO:gensim.matutils:PROGRESS: saving document #214000
# INFO:gensim.matutils:PROGRESS: saving document #215000
# INFO:gensim.matutils:PROGRESS: saving document #216000
# INFO:gensim.matutils:PROGRESS: saving document #217000
# INFO:gensim.matutils:PROGRESS: saving document #218000
# INFO:gensim.matutils:PROGRESS: saving document #219000
# INFO:gensim.matutils:PROGRESS: saving document #220000
# INFO:gensim.matutils:PROGRESS: saving document #221000
# INFO:gensim.matutils:PROGRESS: saving document #222000
# INFO:gensim.matutils:PROGRESS: saving document #223000
# INFO:gensim.matutils:PROGRESS: saving document #224000
# INFO:gensim.matutils:PROGRESS: saving document #225000
# INFO:gensim.matutils:PROGRESS: saving document #226000
# INFO:gensim.matutils:PROGRESS: saving document #227000
# INFO:gensim.matutils:PROGRESS: saving document #228000
# INFO:gensim.matutils:PROGRESS: saving document #229000
# INFO:gensim.matutils:PROGRESS: saving document #230000
# INFO:gensim.matutils:PROGRESS: saving document #231000
# INFO:gensim.matutils:PROGRESS: saving document #232000
# INFO:gensim.matutils:PROGRESS: saving document #233000
# INFO:gensim.matutils:PROGRESS: saving document #234000
# INFO:gensim.matutils:PROGRESS: saving document #235000
# INFO:gensim.matutils:PROGRESS: saving document #236000
# INFO:gensim.matutils:PROGRESS: saving document #237000
# INFO:gensim.matutils:PROGRESS: saving document #238000
# INFO:gensim.matutils:PROGRESS: saving document #239000
# INFO:gensim.matutils:PROGRESS: saving document #240000
# INFO:gensim.matutils:PROGRESS: saving document #241000
# INFO:gensim.matutils:PROGRESS: saving document #242000
# INFO:gensim.matutils:PROGRESS: saving document #243000
# INFO:gensim.matutils:PROGRESS: saving document #244000
# INFO:gensim.matutils:PROGRESS: saving document #245000
# INFO:gensim.matutils:PROGRESS: saving document #246000
# INFO:gensim.matutils:PROGRESS: saving document #247000
# INFO:gensim.matutils:PROGRESS: saving document #248000
# INFO:gensim.matutils:PROGRESS: saving document #249000
# INFO:gensim.matutils:PROGRESS: saving document #250000
# INFO:gensim.matutils:PROGRESS: saving document #251000
# INFO:gensim.matutils:PROGRESS: saving document #252000
# INFO:gensim.matutils:PROGRESS: saving document #253000
# INFO:gensim.matutils:PROGRESS: saving document #254000
# INFO:gensim.matutils:PROGRESS: saving document #255000
# INFO:gensim.matutils:PROGRESS: saving document #256000
# INFO:gensim.matutils:PROGRESS: saving document #257000
# INFO:gensim.matutils:PROGRESS: saving document #258000
# INFO:gensim.matutils:PROGRESS: saving document #259000
# INFO:gensim.matutils:PROGRESS: saving document #260000
# INFO:gensim.matutils:PROGRESS: saving document #261000
# INFO:gensim.matutils:PROGRESS: saving document #262000
# INFO:gensim.matutils:PROGRESS: saving document #263000
# INFO:gensim.matutils:PROGRESS: saving document #264000
# INFO:gensim.matutils:PROGRESS: saving document #265000
# INFO:gensim.matutils:PROGRESS: saving document #266000
# INFO:gensim.matutils:PROGRESS: saving document #267000
# INFO:gensim.matutils:PROGRESS: saving document #268000
# INFO:gensim.matutils:PROGRESS: saving document #269000
# INFO:gensim.matutils:PROGRESS: saving document #270000
# INFO:gensim.matutils:PROGRESS: saving document #271000
# INFO:gensim.matutils:PROGRESS: saving document #272000
# INFO:gensim.matutils:PROGRESS: saving document #273000
# INFO:gensim.matutils:PROGRESS: saving document #274000
# INFO:gensim.matutils:PROGRESS: saving document #275000
# INFO:gensim.matutils:PROGRESS: saving document #276000
# INFO:gensim.matutils:PROGRESS: saving document #277000
# INFO:gensim.matutils:PROGRESS: saving document #278000
# INFO:gensim.matutils:PROGRESS: saving document #279000
# INFO:gensim.matutils:PROGRESS: saving document #280000
# INFO:gensim.matutils:PROGRESS: saving document #281000
# INFO:gensim.matutils:PROGRESS: saving document #282000
# INFO:gensim.matutils:PROGRESS: saving document #283000
# INFO:gensim.matutils:PROGRESS: saving document #284000
# INFO:gensim.matutils:PROGRESS: saving document #285000
# INFO:gensim.matutils:PROGRESS: saving document #286000
# INFO:gensim.matutils:PROGRESS: saving document #287000
# INFO:gensim.matutils:PROGRESS: saving document #288000
# INFO:gensim.matutils:PROGRESS: saving document #289000
# INFO:gensim.matutils:PROGRESS: saving document #290000
# INFO:gensim.matutils:PROGRESS: saving document #291000
# INFO:gensim.matutils:PROGRESS: saving document #292000
# INFO:gensim.matutils:PROGRESS: saving document #293000
# INFO:gensim.matutils:PROGRESS: saving document #294000
# INFO:gensim.matutils:PROGRESS: saving document #295000
# INFO:gensim.matutils:PROGRESS: saving document #296000
# INFO:gensim.matutils:PROGRESS: saving document #297000
# INFO:gensim.matutils:PROGRESS: saving document #298000
# INFO:gensim.matutils:PROGRESS: saving document #299000
# INFO:gensim.matutils:PROGRESS: saving document #300000
# INFO:gensim.matutils:PROGRESS: saving document #301000
# INFO:gensim.matutils:PROGRESS: saving document #302000
# INFO:gensim.matutils:PROGRESS: saving document #303000
# INFO:gensim.matutils:PROGRESS: saving document #304000
# INFO:gensim.matutils:PROGRESS: saving document #305000
# INFO:gensim.matutils:PROGRESS: saving document #306000
# INFO:gensim.matutils:PROGRESS: saving document #307000
# INFO:gensim.matutils:PROGRESS: saving document #308000
# INFO:gensim.matutils:PROGRESS: saving document #309000
# INFO:gensim.matutils:PROGRESS: saving document #310000
# INFO:gensim.matutils:PROGRESS: saving document #311000
# INFO:gensim.matutils:PROGRESS: saving document #312000
# INFO:gensim.matutils:PROGRESS: saving document #313000
# INFO:gensim.matutils:PROGRESS: saving document #314000
# ...
# INFO:gensim.matutils:creating sparse matrix from corpus
# INFO:gensim.matutils:PROGRESS: at document #0/32768
# INFO:gensim.matutils:PROGRESS: at document #10000/32768
# INFO:gensim.matutils:PROGRESS: at document #20000/32768
# INFO:gensim.matutils:PROGRESS: at document #30000/32768
# INFO:gensim.similarities.docsim:created <32768x1286331 sparse matrix of type '<type 'numpy.float32'>'
# 	with 372890 stored elements in Compressed Sparse Row format>
# INFO:gensim.similarities.docsim:creating sparse shard #21
# INFO:gensim.similarities.docsim:saving index shard to /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21
# INFO:gensim.utils:saving SparseMatrixSimilarity object under /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21, separately None
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'wb', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21', mode 'wb' at 0x7f056a55c660>, 'encoding': None}
# INFO:gensim.utils:saved /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21
# DEBUG:gensim.similarities.docsim:mmaping index from /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21
# INFO:gensim.utils:loading SparseMatrixSimilarity object from /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'rb', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'rb', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21', mode 'rb' at 0x7f056a55c8a0>, 'encoding': None}
# INFO:gensim.utils:loaded /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=0
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=10000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=20000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=30000
# INFO:gensim.similarities.docsim:creating sparse index
# INFO:gensim.matutils:creating sparse matrix from corpus
# INFO:gensim.matutils:PROGRESS: at document #0/32768
# INFO:gensim.matutils:PROGRESS: at document #10000/32768
# INFO:gensim.matutils:PROGRESS: at document #20000/32768
# INFO:gensim.matutils:PROGRESS: at document #30000/32768
# INFO:gensim.similarities.docsim:created <32768x1286331 sparse matrix of type '<type 'numpy.float32'>'
# 	with 384124 stored elements in Compressed Sparse Row format>
# INFO:gensim.similarities.docsim:creating sparse shard #22
# INFO:gensim.similarities.docsim:saving index shard to /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22
# INFO:gensim.utils:saving SparseMatrixSimilarity object under /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22, separately None
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'wb', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22', mode 'wb' at 0x7f056a55c660>, 'encoding': None}
# INFO:gensim.utils:saved /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22
# DEBUG:gensim.similarities.docsim:mmaping index from /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22
# INFO:gensim.utils:loading SparseMatrixSimilarity object from /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'rb', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'rb', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22', mode 'rb' at 0x7f056a55c8a0>, 'encoding': None}
# INFO:gensim.utils:loaded /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=0
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=10000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=20000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=30000
# INFO:gensim.similarities.docsim:creating sparse index
# INFO:gensim.matutils:creating sparse matrix from corpus
# INFO:gensim.matutils:PROGRESS: at document #0/32768
# INFO:gensim.matutils:PROGRESS: at document #10000/32768
# INFO:gensim.matutils:PROGRESS: at document #20000/32768
# INFO:gensim.matutils:PROGRESS: at document #30000/32768
# INFO:gensim.similarities.docsim:created <32768x1286331 sparse matrix of type '<type 'numpy.float32'>'
# 	with 410470 stored elements in Compressed Sparse Row format>
# INFO:gensim.similarities.docsim:creating sparse shard #23
# INFO:gensim.similarities.docsim:saving index shard to /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23
# INFO:gensim.utils:saving SparseMatrixSimilarity object under /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23, separately None
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'wb', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23', mode 'wb' at 0x7f056a55c660>, 'encoding': None}
# INFO:gensim.utils:saved /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23
# DEBUG:gensim.similarities.docsim:mmaping index from /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23
# INFO:gensim.utils:loading SparseMatrixSimilarity object from /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'rb', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'rb', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23', mode 'rb' at 0x7f056a55c8a0>, 'encoding': None}
# INFO:gensim.utils:loaded /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=0
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=10000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=20000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=30000
# INFO:gensim.similarities.docsim:creating sparse index
# INFO:gensim.matutils:creating sparse matrix from corpus
# INFO:gensim.matutils:PROGRESS: at document #0/32768
# INFO:gensim.matutils:PROGRESS: at document #10000/32768
# INFO:gensim.matutils:PROGRESS: at document #20000/32768
# INFO:gensim.matutils:PROGRESS: at document #30000/32768
# INFO:gensim.similarities.docsim:created <32768x1286331 sparse matrix of type '<type 'numpy.float32'>'
# 	with 373779 stored elements in Compressed Sparse Row format>
# INFO:gensim.similarities.docsim:creating sparse shard #24
# INFO:gensim.similarities.docsim:saving index shard to /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24
# INFO:gensim.utils:saving SparseMatrixSimilarity object under /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24, separately None
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'wb', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24', mode 'wb' at 0x7f056a55c660>, 'encoding': None}
# INFO:gensim.utils:saved /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24
# DEBUG:gensim.similarities.docsim:mmaping index from /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24
# INFO:gensim.utils:loading SparseMatrixSimilarity object from /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'rb', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'rb', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24', mode 'rb' at 0x7f056a55c8a0>, 'encoding': None}
# INFO:gensim.utils:loaded /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=0
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=10000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=20000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=30000
# INFO:gensim.similarities.docsim:creating sparse index
# INFO:gensim.matutils:creating sparse matrix from corpus
# INFO:gensim.matutils:PROGRESS: at document #0/32768
# INFO:gensim.matutils:PROGRESS: at document #10000/32768
# INFO:gensim.matutils:PROGRESS: at document #20000/32768
# INFO:gensim.matutils:PROGRESS: at document #30000/32768
# INFO:gensim.similarities.docsim:created <32768x1286331 sparse matrix of type '<type 'numpy.float32'>'
# 	with 346438 stored elements in Compressed Sparse Row format>
# INFO:gensim.similarities.docsim:creating sparse shard #25
# INFO:gensim.similarities.docsim:saving index shard to /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25
# INFO:gensim.utils:saving SparseMatrixSimilarity object under /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25, separately None
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'wb', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25', mode 'wb' at 0x7f056a55c660>, 'encoding': None}
# INFO:gensim.utils:saved /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25
# DEBUG:gensim.similarities.docsim:mmaping index from /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25
# INFO:gensim.utils:loading SparseMatrixSimilarity object from /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'rb', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'rb', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25', mode 'rb' at 0x7f056a55c8a0>, 'encoding': None}
# INFO:gensim.utils:loaded /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=0
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=10000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=20000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=30000
# INFO:gensim.similarities.docsim:creating sparse index
# INFO:gensim.matutils:creating sparse matrix from corpus
# INFO:gensim.matutils:PROGRESS: at document #0/32768
# INFO:gensim.matutils:PROGRESS: at document #10000/32768
# INFO:gensim.matutils:PROGRESS: at document #20000/32768
# INFO:gensim.matutils:PROGRESS: at document #30000/32768
# INFO:gensim.similarities.docsim:created <32768x1286331 sparse matrix of type '<type 'numpy.float32'>'
# 	with 365748 stored elements in Compressed Sparse Row format>
# INFO:gensim.similarities.docsim:creating sparse shard #26
# INFO:gensim.similarities.docsim:saving index shard to /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26
# INFO:gensim.utils:saving SparseMatrixSimilarity object under /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26, separately None
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'wb', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26', mode 'wb' at 0x7f056a55c660>, 'encoding': None}
# INFO:gensim.utils:saved /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26
# DEBUG:gensim.similarities.docsim:mmaping index from /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26
# INFO:gensim.utils:loading SparseMatrixSimilarity object from /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'rb', 'uri': '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'rb', 'fileobj': <open file '/scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26', mode 'rb' at 0x7f056a55c8a0>, 'encoding': None}
# INFO:gensim.utils:loaded /scratch/home/hwzha/workspace/rake/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=0
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=10000

# %%
APPROACHES = ['econ']
for dataset in ['database', 'machine_learning', 'pubmed']:
    for approach in APPROACHES:
        process(dataset, approach)
# Out:
# [Errno 2] No such file or directory: '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/database/merged.txt_without_sentence_id.evaluation.txt'
# DEBUG:root:processing /scratch/home/hwzha/workspace/StructMineDataPipeline/result/machine_learning/merged.txt_without_sentence_id.evaluation.txt
# using new model
# INFO:gensim.corpora.dictionary:adding document #0 to Dictionary(0 unique tokens: [])
# INFO:gensim.corpora.dictionary:adding document #10000 to Dictionary(18566 unique tokens: [u'<c>many_open_questions</c>', u'1tilo', u'<c>fitting_tasks</c>', u'<c>and_queries</c>', u'<c>phenomena</c>']...)
# INFO:gensim.corpora.dictionary:adding document #20000 to Dictionary(31666 unique tokens: [u'<c>k_scaling</c>', u'<c>subgradient</c>', u'<c>complexity_measure_c</c>', u'<c>alexandros</c>', u'<c>integer_values</c>']...)
# INFO:gensim.corpora.dictionary:adding document #30000 to Dictionary(43975 unique tokens: [u'<c>utility_functions</c>', u'<c>k_scaling</c>', u'<c>subgradient</c>', u'<c>transferrable_functions</c>', u'<c>complexity_measure_c</c>']...)
# INFO:gensim.corpora.dictionary:adding document #40000 to Dictionary(55690 unique tokens: [u'<c>capital_letters</c>', u'<c>utility_functions</c>', u'<c>k_scaling</c>', u'<c>subgradient</c>', u'<c>neural_models</c>']...)
# INFO:gensim.corpora.dictionary:adding document #50000 to Dictionary(66513 unique tokens: [u'<c>capital_letters</c>', u'<c>utility_functions</c>', u'<c>k_scaling</c>', u'<c>subgradient</c>', u'<c>neural_models</c>']...)
# INFO:gensim.corpora.dictionary:adding document #60000 to Dictionary(76575 unique tokens: [u'<c>capital_letters</c>', u'<c>utility_functions</c>', u'<c>k_scaling</c>', u'<c>subgradient</c>', u'<c>neural_models</c>']...)
# INFO:gensim.corpora.dictionary:adding document #70000 to Dictionary(87265 unique tokens: [u'<c>capital_letters</c>', u'<c>utility_functions</c>', u'<c>k_scaling</c>', u'<c>subgradient</c>', u'<c>neural_models</c>']...)
# INFO:gensim.corpora.dictionary:adding document #80000 to Dictionary(96254 unique tokens: [u'<c>capital_letters</c>', u'<c>subgradient</c>', u'<c>current_candidate</c>', u'<c>neural_models</c>', u'<c>satisfactory_robustness</c>']...)
# INFO:gensim.corpora.dictionary:adding document #90000 to Dictionary(105870 unique tokens: [u'<c>capital_letters</c>', u'<c>subgradient</c>', u'<c>current_candidate</c>', u'<c>neural_models</c>', u'<c>satisfactory_robustness</c>']...)
# INFO:gensim.corpora.dictionary:adding document #100000 to Dictionary(115809 unique tokens: [u'<c>capital_letters</c>', u'<c>stream_on-the-fly</c>', u'<c>subgradient</c>', u'<c>current_candidate</c>', u'<c>neural_models</c>']...)
# INFO:gensim.corpora.dictionary:adding document #110000 to Dictionary(124911 unique tokens: [u'<c>capital_letters</c>', u'<c>stream_on-the-fly</c>', u'<c>subgradient</c>', u'<c>current_candidate</c>', u'<c>neural_models</c>']...)
# INFO:gensim.corpora.dictionary:adding document #120000 to Dictionary(134914 unique tokens: [u'<c>capital_letters</c>', u'<c>stream_on-the-fly</c>', u'<c>subgradient</c>', u'<c>current_candidate</c>', u'<c>neural_models</c>']...)
# INFO:gensim.corpora.dictionary:adding document #130000 to Dictionary(143870 unique tokens: [u'<c>capital_letters</c>', u'<c>stream_on-the-fly</c>', u'<c>detailed_visual_appearances</c>', u'<c>subgradient</c>', u'<c>current_candidate</c>']...)
# INFO:gensim.corpora.dictionary:adding document #140000 to Dictionary(152490 unique tokens: [u'<c>capital_letters</c>', u'<c>stream_on-the-fly</c>', u'<c>detailed_visual_appearances</c>', u'<c>subgradient</c>', u'<c>current_candidate</c>']...)
# INFO:gensim.corpora.dictionary:adding document #150000 to Dictionary(161542 unique tokens: [u'<c>capital_letters</c>', u'<c>stream_on-the-fly</c>', u'<c>detailed_visual_appearances</c>', u'<c>subgradient</c>', u'<c>current_candidate</c>']...)
# INFO:gensim.corpora.dictionary:adding document #160000 to Dictionary(170158 unique tokens: [u'<c>capital_letters</c>', u'<c>stream_on-the-fly</c>', u'<c>detailed_visual_appearances</c>', u'<c>subgradient</c>', u'<c>current_candidate</c>']...)
# INFO:gensim.corpora.dictionary:adding document #170000 to Dictionary(178347 unique tokens: [u'<c>capital_letters</c>', u'<c>matthew_johnson</c>', u'<c>neural_models</c>', u'<c>alexandros</c>', u'<c>urban_system</c>']...)
# INFO:gensim.corpora.dictionary:adding document #180000 to Dictionary(186050 unique tokens: [u'<c>capital_letters</c>', u'<c>matthew_johnson</c>', u'<c>neural_models</c>', u'<c>alexandros</c>', u'<c>urban_system</c>']...)
# INFO:gensim.corpora.dictionary:adding document #190000 to Dictionary(194566 unique tokens: [u'<c>capital_letters</c>', u'<c>matthew_johnson</c>', u'<c>neural_models</c>', u'<c>t_time</c>', u'<c>alexandros</c>']...)
# INFO:gensim.corpora.dictionary:adding document #200000 to Dictionary(202639 unique tokens: [u'<c>capital_letters</c>', u'<c>matthew_johnson</c>', u'<c>neural_models</c>', u'<c>t_time</c>', u'<c>alexandros</c>']...)
# INFO:gensim.corpora.dictionary:adding document #210000 to Dictionary(210903 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>matthew_johnson</c>', u'<c>neural_models</c>', u'<c>t_time</c>']...)
# INFO:gensim.corpora.dictionary:adding document #220000 to Dictionary(219002 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>matthew_johnson</c>', u'<c>neural_models</c>', u'<c>t_time</c>']...)
# INFO:gensim.corpora.dictionary:adding document #230000 to Dictionary(227365 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>matthew_johnson</c>', u'<c>neural_models</c>', u'<c>t_time</c>']...)
# INFO:gensim.corpora.dictionary:adding document #240000 to Dictionary(234798 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>matthew_johnson</c>', u'<c>neural_models</c>', u'<c>t_time</c>']...)
# INFO:gensim.corpora.dictionary:adding document #250000 to Dictionary(242201 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>matthew_johnson</c>', u'<c>neural_models</c>']...)
# INFO:gensim.corpora.dictionary:adding document #260000 to Dictionary(249236 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>matthew_johnson</c>', u'<c>neural_models</c>']...)
# INFO:gensim.corpora.dictionary:adding document #270000 to Dictionary(257975 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>matthew_johnson</c>', u'<c>neural_models</c>']...)
# INFO:gensim.corpora.dictionary:adding document #280000 to Dictionary(266571 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>matthew_johnson</c>', u'<c>neural_models</c>']...)
# INFO:gensim.corpora.dictionary:adding document #290000 to Dictionary(276267 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>common_terminology</c>', u'<c>anks</c>', u'<c>complex_visual_entities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #300000 to Dictionary(286353 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>common_terminology</c>', u'<c>anks</c>', u'<c>complex_visual_entities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #310000 to Dictionary(294888 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>common_terminology</c>', u'<c>anks</c>', u'<c>complex_visual_entities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #320000 to Dictionary(303572 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>common_terminology</c>', u'<c>anks</c>', u'<c>complex_visual_entities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #330000 to Dictionary(311467 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>common_terminology</c>', u'<c>anks</c>', u'<c>complex_visual_entities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #340000 to Dictionary(318815 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>common_terminology</c>', u'<c>anks</c>', u'<c>complex_visual_entities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #350000 to Dictionary(326045 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>common_terminology</c>', u'<c>anks</c>', u'<c>complex_visual_entities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #360000 to Dictionary(334308 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>common_terminology</c>', u'<c>anks</c>', u'<c>complex_visual_entities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #370000 to Dictionary(342232 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>common_terminology</c>', u'<c>anks</c>', u'<c>complex_visual_entities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #380000 to Dictionary(349254 unique tokens: [u'<c>vector_augmentation</c>', u'<c>capital_letters</c>', u'<c>common_terminology</c>', u'<c>anks</c>', u'<c>complex_visual_entities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #390000 to Dictionary(357576 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>', u'<c>urban_system</c>']...)
# INFO:gensim.corpora.dictionary:adding document #400000 to Dictionary(364851 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>', u'<c>urban_system</c>']...)
# INFO:gensim.corpora.dictionary:adding document #410000 to Dictionary(371904 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>', u'<c>urban_system</c>']...)
# INFO:gensim.corpora.dictionary:adding document #420000 to Dictionary(379789 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>', u'<c>urban_system</c>']...)
# INFO:gensim.corpora.dictionary:adding document #430000 to Dictionary(386527 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #440000 to Dictionary(393815 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #450000 to Dictionary(400736 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #460000 to Dictionary(408028 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #470000 to Dictionary(415868 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #480000 to Dictionary(422965 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #490000 to Dictionary(429465 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #500000 to Dictionary(436459 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #510000 to Dictionary(444018 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #520000 to Dictionary(451331 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #530000 to Dictionary(458511 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #540000 to Dictionary(465630 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #550000 to Dictionary(472345 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #560000 to Dictionary(479615 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #570000 to Dictionary(489959 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #580000 to Dictionary(499056 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #590000 to Dictionary(505928 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #600000 to Dictionary(512786 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #610000 to Dictionary(519681 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #620000 to Dictionary(526491 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #630000 to Dictionary(533165 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #640000 to Dictionary(539990 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #650000 to Dictionary(548638 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #660000 to Dictionary(557348 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #670000 to Dictionary(565516 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #680000 to Dictionary(573943 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #690000 to Dictionary(581740 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #700000 to Dictionary(590008 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #710000 to Dictionary(596507 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>information_divergences_topsoe</c>']...)
# INFO:gensim.corpora.dictionary:adding document #720000 to Dictionary(602714 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>information_divergences_topsoe</c>']...)
# INFO:gensim.corpora.dictionary:adding document #730000 to Dictionary(609321 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>information_divergences_topsoe</c>']...)
# INFO:gensim.corpora.dictionary:adding document #740000 to Dictionary(616591 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>information_divergences_topsoe</c>']...)
# INFO:gensim.corpora.dictionary:adding document #750000 to Dictionary(623121 unique tokens: [u'<c>capital_letters</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>', u'<c>information_divergences_topsoe</c>']...)
# INFO:gensim.corpora.dictionary:adding document #760000 to Dictionary(629871 unique tokens: [u'<c>capital_letters</c>', u'<c>covariance_matrix_principal_components</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>']...)
# INFO:gensim.corpora.dictionary:adding document #770000 to Dictionary(636667 unique tokens: [u'<c>capital_letters</c>', u'<c>covariance_matrix_principal_components</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>']...)
# INFO:gensim.corpora.dictionary:adding document #780000 to Dictionary(643037 unique tokens: [u'<c>capital_letters</c>', u'<c>covariance_matrix_principal_components</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>']...)
# INFO:gensim.corpora.dictionary:adding document #790000 to Dictionary(650514 unique tokens: [u'<c>capital_letters</c>', u'<c>covariance_matrix_principal_components</c>', u'<c>complex_visual_entities</c>', u'<c>one-vs-all_setting</c>', u'<c>o_winther_thanks_pedro_h_jen-s_rensen</c>']...)
# INFO:gensim.corpora.dictionary:adding document #800000 to Dictionary(657203 unique tokens: [u'<c>capital_letters</c>', u'<c>covariance_matrix_principal_components</c>', u'<c>complex_visual_entities</c>', u'<c>map_image_estimate</c>', u'<c>one-vs-all_setting</c>']...)
# INFO:gensim.corpora.dictionary:adding document #810000 to Dictionary(663932 unique tokens: [u'<c>capital_letters</c>', u'<c>covariance_matrix_principal_components</c>', u'<c>complex_visual_entities</c>', u'<c>map_image_estimate</c>', u'<c>one-vs-all_setting</c>']...)
# INFO:gensim.corpora.dictionary:adding document #820000 to Dictionary(670779 unique tokens: [u'<c>capital_letters</c>', u'<c>covariance_matrix_principal_components</c>', u'<c>complex_visual_entities</c>', u'<c>map_image_estimate</c>', u'<c>one-vs-all_setting</c>']...)
# INFO:gensim.corpora.dictionary:adding document #830000 to Dictionary(677628 unique tokens: [u'<c>capital_letters</c>', u'<c>covariance_matrix_principal_components</c>', u'<c>complex_visual_entities</c>', u'<c>map_image_estimate</c>', u'<c>one-vs-all_setting</c>']...)
# INFO:gensim.corpora.dictionary:adding document #840000 to Dictionary(684179 unique tokens: [u'<c>capital_letters</c>', u'<c>covariance_matrix_principal_components</c>', u'<c>complex_visual_entities</c>', u'<c>map_image_estimate</c>', u'<c>one-vs-all_setting</c>']...)
# INFO:gensim.corpora.dictionary:adding document #850000 to Dictionary(690763 unique tokens: [u'<c>capital_letters</c>', u'<c>covariance_matrix_principal_components</c>', u'<c>complex_visual_entities</c>', u'<c>map_image_estimate</c>', u'<c>one-vs-all_setting</c>']...)
# INFO:gensim.corpora.dictionary:adding document #860000 to Dictionary(697503 unique tokens: [u'<c>capital_letters</c>', u'<c>covariance_matrix_principal_components</c>', u'<c>complex_visual_entities</c>', u'<c>map_image_estimate</c>', u'<c>one-vs-all_setting</c>']...)
# INFO:gensim.corpora.dictionary:adding document #870000 to Dictionary(703808 unique tokens: [u'<c>one-vs-all_setting</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>', u'<c>tth_batch</c>', u'<c>true_probabilities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #880000 to Dictionary(710437 unique tokens: [u'<c>one-vs-all_setting</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>', u'<c>tth_batch</c>', u'<c>true_probabilities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #890000 to Dictionary(716821 unique tokens: [u'<c>one-vs-all_setting</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>', u'<c>tth_batch</c>', u'<c>true_probabilities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #900000 to Dictionary(722931 unique tokens: [u'<c>one-vs-all_setting</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>', u'<c>tth_batch</c>', u'<c>true_probabilities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #910000 to Dictionary(729806 unique tokens: [u'<c>one-vs-all_setting</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>', u'<c>tth_batch</c>', u'<c>true_probabilities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #920000 to Dictionary(736226 unique tokens: [u'<c>one-vs-all_setting</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>', u'<c>tth_batch</c>', u'<c>true_probabilities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #930000 to Dictionary(742945 unique tokens: [u'<c>one-vs-all_setting</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>', u'<c>tth_batch</c>', u'<c>true_probabilities</c>']...)
# INFO:gensim.corpora.dictionary:adding document #940000 to Dictionary(749338 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>', u'<c>tth_batch</c>']...)
# INFO:gensim.corpora.dictionary:adding document #950000 to Dictionary(755469 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>', u'<c>tth_batch</c>']...)
# INFO:gensim.corpora.dictionary:adding document #960000 to Dictionary(761709 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>', u'<c>tth_batch</c>']...)
# INFO:gensim.corpora.dictionary:adding document #970000 to Dictionary(767783 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #980000 to Dictionary(773355 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #990000 to Dictionary(779272 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1000000 to Dictionary(785455 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1010000 to Dictionary(791686 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1020000 to Dictionary(797380 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1030000 to Dictionary(803740 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1040000 to Dictionary(809457 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1050000 to Dictionary(815773 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1060000 to Dictionary(821855 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1070000 to Dictionary(827440 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1080000 to Dictionary(834138 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1090000 to Dictionary(842045 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1100000 to Dictionary(849398 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1110000 to Dictionary(856802 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1120000 to Dictionary(863121 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1130000 to Dictionary(869249 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1140000 to Dictionary(875340 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1150000 to Dictionary(881373 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1160000 to Dictionary(887180 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1170000 to Dictionary(893035 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1180000 to Dictionary(898937 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1190000 to Dictionary(904715 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1200000 to Dictionary(911162 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1210000 to Dictionary(917506 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1220000 to Dictionary(923201 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1230000 to Dictionary(929512 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1240000 to Dictionary(935318 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1250000 to Dictionary(940762 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1260000 to Dictionary(946769 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1270000 to Dictionary(952355 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1280000 to Dictionary(957786 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1290000 to Dictionary(963230 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>training-set_fractions</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1300000 to Dictionary(970377 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1310000 to Dictionary(975908 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1320000 to Dictionary(984208 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1330000 to Dictionary(992528 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1340000 to Dictionary(1000412 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1350000 to Dictionary(1008195 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1360000 to Dictionary(1015296 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1370000 to Dictionary(1020999 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1380000 to Dictionary(1027555 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1390000 to Dictionary(1034110 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1400000 to Dictionary(1040244 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1410000 to Dictionary(1046308 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1420000 to Dictionary(1051334 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1430000 to Dictionary(1056954 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1440000 to Dictionary(1062650 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1450000 to Dictionary(1068203 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1460000 to Dictionary(1074046 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1470000 to Dictionary(1080199 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1480000 to Dictionary(1085568 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1490000 to Dictionary(1091168 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1500000 to Dictionary(1096468 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1510000 to Dictionary(1101656 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1520000 to Dictionary(1106591 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1530000 to Dictionary(1112501 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1540000 to Dictionary(1118264 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1550000 to Dictionary(1124007 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1560000 to Dictionary(1131270 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1570000 to Dictionary(1138605 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1580000 to Dictionary(1145461 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1590000 to Dictionary(1152967 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1600000 to Dictionary(1160409 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1610000 to Dictionary(1167405 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1620000 to Dictionary(1172740 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1630000 to Dictionary(1178432 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1640000 to Dictionary(1184676 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1650000 to Dictionary(1190299 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1660000 to Dictionary(1195592 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1670000 to Dictionary(1201379 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1680000 to Dictionary(1206982 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1690000 to Dictionary(1212732 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1700000 to Dictionary(1219091 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1710000 to Dictionary(1226057 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1720000 to Dictionary(1232623 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1730000 to Dictionary(1239144 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1740000 to Dictionary(1244951 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1750000 to Dictionary(1250404 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1760000 to Dictionary(1256150 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1770000 to Dictionary(1261316 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1780000 to Dictionary(1267208 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1790000 to Dictionary(1272825 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1800000 to Dictionary(1277967 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1810000 to Dictionary(1283618 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1820000 to Dictionary(1289145 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1830000 to Dictionary(1293861 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1840000 to Dictionary(1298594 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1850000 to Dictionary(1303881 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1860000 to Dictionary(1311066 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1870000 to Dictionary(1317978 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1880000 to Dictionary(1325291 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1890000 to Dictionary(1331695 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1900000 to Dictionary(1338513 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# INFO:gensim.corpora.dictionary:adding document #1910000 to Dictionary(1345119 unique tokens: [u'<c>one-vs-all_setting</c>', u'3:273', u'<c>multivew_face_detection</c>', u'<c>spatial_forms</c>', u'<c>adversarial_non-stochastic_multi-armed_bandit</c>']...)
# ...
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb', 'fileobj': <open file '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21', mode 'wb' at 0x7f05843ebdb0>, 'encoding': None}
# INFO:gensim.utils:saved /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21
# DEBUG:gensim.similarities.docsim:mmaping index from /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21
# INFO:gensim.utils:loading SparseMatrixSimilarity object from /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'rb', 'uri': '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'rb', 'fileobj': <open file '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21', mode 'rb' at 0x7f05843ebed0>, 'encoding': None}
# INFO:gensim.utils:loaded /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.21
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=0
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=10000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=20000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=30000
# INFO:gensim.similarities.docsim:creating sparse index
# INFO:gensim.matutils:creating sparse matrix from corpus
# INFO:gensim.matutils:PROGRESS: at document #0/32768
# INFO:gensim.matutils:PROGRESS: at document #10000/32768
# INFO:gensim.matutils:PROGRESS: at document #20000/32768
# INFO:gensim.matutils:PROGRESS: at document #30000/32768
# INFO:gensim.similarities.docsim:created <32768x917330 sparse matrix of type '<type 'numpy.float32'>'
# 	with 416714 stored elements in Compressed Sparse Row format>
# INFO:gensim.similarities.docsim:creating sparse shard #22
# INFO:gensim.similarities.docsim:saving index shard to /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22
# INFO:gensim.utils:saving SparseMatrixSimilarity object under /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22, separately None
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'wb', 'uri': '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb', 'fileobj': <open file '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22', mode 'wb' at 0x7f05843ebdb0>, 'encoding': None}
# INFO:gensim.utils:saved /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22
# DEBUG:gensim.similarities.docsim:mmaping index from /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22
# INFO:gensim.utils:loading SparseMatrixSimilarity object from /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'rb', 'uri': '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'rb', 'fileobj': <open file '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22', mode 'rb' at 0x7f05843ebed0>, 'encoding': None}
# INFO:gensim.utils:loaded /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.22
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=0
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=10000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=20000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=30000
# INFO:gensim.similarities.docsim:creating sparse index
# INFO:gensim.matutils:creating sparse matrix from corpus
# INFO:gensim.matutils:PROGRESS: at document #0/32768
# INFO:gensim.matutils:PROGRESS: at document #10000/32768
# INFO:gensim.matutils:PROGRESS: at document #20000/32768
# INFO:gensim.matutils:PROGRESS: at document #30000/32768
# INFO:gensim.similarities.docsim:created <32768x917330 sparse matrix of type '<type 'numpy.float32'>'
# 	with 429047 stored elements in Compressed Sparse Row format>
# INFO:gensim.similarities.docsim:creating sparse shard #23
# INFO:gensim.similarities.docsim:saving index shard to /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23
# INFO:gensim.utils:saving SparseMatrixSimilarity object under /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23, separately None
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'wb', 'uri': '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb', 'fileobj': <open file '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23', mode 'wb' at 0x7f05843ebdb0>, 'encoding': None}
# INFO:gensim.utils:saved /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23
# DEBUG:gensim.similarities.docsim:mmaping index from /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23
# INFO:gensim.utils:loading SparseMatrixSimilarity object from /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'rb', 'uri': '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'rb', 'fileobj': <open file '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23', mode 'rb' at 0x7f05843ebed0>, 'encoding': None}
# INFO:gensim.utils:loaded /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.23
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=0
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=10000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=20000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=30000
# INFO:gensim.similarities.docsim:creating sparse index
# INFO:gensim.matutils:creating sparse matrix from corpus
# INFO:gensim.matutils:PROGRESS: at document #0/32768
# INFO:gensim.matutils:PROGRESS: at document #10000/32768
# INFO:gensim.matutils:PROGRESS: at document #20000/32768
# INFO:gensim.matutils:PROGRESS: at document #30000/32768
# INFO:gensim.similarities.docsim:created <32768x917330 sparse matrix of type '<type 'numpy.float32'>'
# 	with 401006 stored elements in Compressed Sparse Row format>
# INFO:gensim.similarities.docsim:creating sparse shard #24
# INFO:gensim.similarities.docsim:saving index shard to /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24
# INFO:gensim.utils:saving SparseMatrixSimilarity object under /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24, separately None
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'wb', 'uri': '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb', 'fileobj': <open file '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24', mode 'wb' at 0x7f05843ebdb0>, 'encoding': None}
# INFO:gensim.utils:saved /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24
# DEBUG:gensim.similarities.docsim:mmaping index from /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24
# INFO:gensim.utils:loading SparseMatrixSimilarity object from /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'rb', 'uri': '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'rb', 'fileobj': <open file '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24', mode 'rb' at 0x7f05843ebed0>, 'encoding': None}
# INFO:gensim.utils:loaded /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.24
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=0
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=10000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=20000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=30000
# INFO:gensim.similarities.docsim:creating sparse index
# INFO:gensim.matutils:creating sparse matrix from corpus
# INFO:gensim.matutils:PROGRESS: at document #0/32768
# INFO:gensim.matutils:PROGRESS: at document #10000/32768
# INFO:gensim.matutils:PROGRESS: at document #20000/32768
# INFO:gensim.matutils:PROGRESS: at document #30000/32768
# INFO:gensim.similarities.docsim:created <32768x917330 sparse matrix of type '<type 'numpy.float32'>'
# 	with 379737 stored elements in Compressed Sparse Row format>
# INFO:gensim.similarities.docsim:creating sparse shard #25
# INFO:gensim.similarities.docsim:saving index shard to /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25
# INFO:gensim.utils:saving SparseMatrixSimilarity object under /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25, separately None
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'wb', 'uri': '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb', 'fileobj': <open file '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25', mode 'wb' at 0x7f05843ebdb0>, 'encoding': None}
# INFO:gensim.utils:saved /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25
# DEBUG:gensim.similarities.docsim:mmaping index from /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25
# INFO:gensim.utils:loading SparseMatrixSimilarity object from /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'rb', 'uri': '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'rb', 'fileobj': <open file '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25', mode 'rb' at 0x7f05843ebed0>, 'encoding': None}
# INFO:gensim.utils:loaded /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.25
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=0
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=10000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=20000
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=30000
# INFO:gensim.similarities.docsim:creating sparse index
# INFO:gensim.matutils:creating sparse matrix from corpus
# INFO:gensim.matutils:PROGRESS: at document #0/32768
# INFO:gensim.matutils:PROGRESS: at document #10000/32768
# INFO:gensim.matutils:PROGRESS: at document #20000/32768
# INFO:gensim.matutils:PROGRESS: at document #30000/32768
# INFO:gensim.similarities.docsim:created <32768x917330 sparse matrix of type '<type 'numpy.float32'>'
# 	with 403412 stored elements in Compressed Sparse Row format>
# INFO:gensim.similarities.docsim:creating sparse shard #26
# INFO:gensim.similarities.docsim:saving index shard to /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26
# INFO:gensim.utils:saving SparseMatrixSimilarity object under /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26, separately None
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'wb', 'uri': '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'wb', 'fileobj': <open file '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26', mode 'wb' at 0x7f05843ebdb0>, 'encoding': None}
# INFO:gensim.utils:saved /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26
# DEBUG:gensim.similarities.docsim:mmaping index from /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26
# INFO:gensim.utils:loading SparseMatrixSimilarity object from /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26
# DEBUG:smart_open.smart_open_lib:{'kw': {}, 'mode': 'rb', 'uri': '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26'}
# DEBUG:smart_open.smart_open_lib:encoding_wrapper: {'errors': 'strict', 'mode': 'rb', 'fileobj': <open file '/scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26', mode 'rb' at 0x7f05843ebed0>, 'encoding': None}
# INFO:gensim.utils:loaded /scratch/home/hwzha/workspace/StructMineDataPipeline/result/pubmed/merged.txt_without_sentence_id.evaluation.txt.modelTfidfindex.26
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=0
# INFO:gensim.similarities.docsim:PROGRESS: fresh_shard size=10000
